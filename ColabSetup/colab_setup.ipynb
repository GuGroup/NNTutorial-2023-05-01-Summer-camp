# %% [markdown]
# # Google Colab 튜토리얼
# ## 1. Why Google Colab?
# Google Colab은 무료 온라인 GPU를 제공하여 파이썬에서 pytorch, tensorflow를 사용하여 딥 러닝 모델을 사용할 수 있습니다. GPU가 없는 초보자들에게는 GPU를 사용하여 연습할 수 있는 인터페이스를 제공합니다.
#
# ## 2. Getting started with Colab
# Google 계정 로그인 후 Google colab 웹사이트로 간다.
#
# <img src="img/img1.png" style="max-width: 800px;">
#
# 오른쪽 아래에 뉴 노트북을 누른다.
#
# <img src="img/img2.png" style="max-width: 800px;">
#
# Change the note name to if you would like.
#
# <img src="img/img3.png" style="max-width: 800px;">
#
# You can run a block of your code by clicking the arrow button, or ctrl+ enter. You can add a block by clicking "+ Code"
#
# <img src="img/img4.png" style="max-width: 800px;">
#
# ## 3. GPU
#
# Change your setting y going to **[Edit] → [Notebook settings] → [Hardware accelerator] → [None]** Change to **[GPU] → [Save]** Now you can use a GPU provided by Google.
#
# <img src="img/img5.png" style="max-width: 800px;">
#
# <img src="img/img6.png" style="max-width: 800px;">
#
# You can enter "!nvidia-smi" to see the GPU status.
#
# <img src="img/img7.png" style="max-width: 800px;">
#
# ## 4. Google Drive
#
# Click the folder icon on the left bar, and click the Google drive icon.
#
# <img src="img/img8.png" style="max-width: 800px;">
#
# Give permission to Google Colab to access your Google Drive
#
# <img src="img/img9.png" style="max-width: 800px;">
#
# You can see that your Colab has been connected to the google drive. The files in **[drive] → [MyDrive]** are the files in your Google Drive.
#
# <img src="img/img10.png" style="max-width: 800px;">
#
# You can also connect to Google Drive using following command.
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# ```
#
# ## 5. Prevent Disconnection
#
# The Colab automatically disconnects after 30 minutes, which could lose your precious data. Following the advice here: https://medium.com/@shivamrawat_756/how-to-prevent-google-colab-from-disconnecting-717b88a128c0
# You can do the following on Google Chrome:
# Ctrl + Shift + i to open inspector view, and go to console, and type the follow:
#
# ```
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button").click()
# }setInterval(ClickConnect,60000)
# ```
#
# <img src="img/img11.png" style="max-width: 800px;">
